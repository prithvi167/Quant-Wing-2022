# %%
import numpy as np
import scipy.optimize as spop
import pandas as pd
import yfinance as yf
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

# %%
stocks = ['JPM', 'AAPL', 'HDB', 'V.MX', 'SBIN.NS', 'MCD', 'GOOG', 'RS', 'MSFT', 'CIPLA.BO']
start = '2019-12-31'
end = '2022-08-20'
fee = 0.001
window = 252
t_threshold = -2.5
data = pd.DataFrame()
returns = pd.DataFrame()
for stock in stocks:
    prices = yf.download(stock, start, end)
    data[stock] = prices['Close']
    returns[stock] = np.append(data[stock][1:].reset_index(drop=True)/data[stock][:-1].reset_index(drop=True) - 1, 0)

# %%
data
# Out:
#                    JPM        AAPL        HDB         V.MX     SBIN.NS  \
# Date
# 2019-12-30  138.630005   72.879997  62.939999  3543.000000         NaN
# 2019-12-31  139.399994   73.412498  63.369999  3543.000000  333.750000
# 2020-01-02  141.089996   75.087502  63.700001  3591.000000  339.299988
# 2020-01-03  138.339996   74.357498  62.009998  3600.000000  333.700012
# 2020-01-06  138.229996   74.949997  60.910000  3577.500000  319.000000
# ...                ...         ...        ...          ...         ...
# 2022-08-15  122.459999  173.190002  65.760002  4260.000000         NaN
# 2022-08-16  123.629997  173.029999  64.940002  4366.919922  525.950012
# 2022-08-17  122.589996  174.550003  64.610001  4261.819824  528.150024
# 2022-08-18  121.639999  174.149994  64.620003  4340.000000  532.349976
# 2022-08-19  118.629997  171.520004  63.049999  4315.000000  520.349976
#
#                    MCD        GOOG          RS        MSFT     CIPLA.BO
# Date
# 2019-12-30  196.910004   66.806999  120.089996  157.589996          NaN
# 2019-12-31  197.610001   66.850998  119.760002  157.699997   478.450012
# 2020-01-02  200.789993   68.368500  119.250000  160.619995   473.700012
# 2020-01-03  200.080002   68.032997  118.809998  158.619995   470.250000
# 2020-01-06  202.330002   69.710503  118.519997  159.029999   466.750000
# ...                ...         ...         ...         ...          ...
# 2022-08-15  265.440002  122.879997  196.050003  293.470001          NaN
# 2022-08-16  266.290009  122.510002  197.429993  292.709991  1033.849976
# 2022-08-17  266.820007  120.320000  194.800003  291.320007  1025.500000
# 2022-08-18  266.579987  120.860001  195.080002  290.170013  1032.099976
# 2022-08-19  266.540009  118.120003  191.679993  286.149994  1030.349976
#
# [666 rows x 10 columns]

# %%
returns
# Out:
#           JPM      AAPL       HDB      V.MX   SBIN.NS       MCD      GOOG  \
# 0    0.005554  0.007307  0.006832  0.000000       NaN  0.003555  0.000659
# 1    0.012123  0.022816  0.005208  0.013548  0.016629  0.016092  0.022700
# 2   -0.019491 -0.009722 -0.026531  0.002506 -0.016504 -0.003536 -0.004907
# 3   -0.000795  0.007968 -0.017739 -0.006250 -0.044052  0.011246  0.024657
# 4   -0.017001 -0.004703 -0.003612 -0.004612 -0.001881  0.001483 -0.000624
# ..        ...       ...       ...       ...       ...       ...       ...
# 661  0.009554 -0.000924 -0.012470  0.025099       NaN  0.003202 -0.003011
# 662 -0.008412  0.008785 -0.005082 -0.024067  0.004183  0.001990 -0.017876
# 663 -0.007749 -0.002292  0.000155  0.018344  0.007952 -0.000900  0.004488
# 664 -0.024745 -0.015102 -0.024296 -0.005760 -0.022542 -0.000150 -0.022671
# 665  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#            RS      MSFT  CIPLA.BO
# 0   -0.002748  0.000698       NaN
# 1   -0.004259  0.018516 -0.009928
# 2   -0.003690 -0.012452 -0.007283
# 3   -0.002441  0.002585 -0.007443
# 4    0.002784 -0.009118  0.004285
# ..        ...       ...       ...
# 661  0.007039 -0.002590       NaN
# 662 -0.013321 -0.004749 -0.008077
# 663  0.001437 -0.003948  0.006436
# 664 -0.017429 -0.013854 -0.001696
# 665  0.000000  0.000000  0.000000
#
# [666 rows x 10 columns]

# %%
#initialising arrays
gross_returns = np.array([])
net_returns = np.array([])
t_s = np.array([])
for i in range(0, 10):
    stock1 = stocks[0]
    for j in range(0, i+1):
        stock2 = stocks[1]
    #moving through the sample
    for t in range(window, len(data)):
        #defining the unit root function: stock2 = a + b*stock1
        def unit_root(b):
            a = np.average(data[stock2][t-window:t] - b*data[stock1][t-window:t])
            fair_value = a + b*data[stock1][t-window:t]
            diff = np.array(fair_value - data[stock2][t-window:t])
            diff_diff = diff[1:] - diff[:-1]
            reg = sm.OLS(diff_diff, diff[:-1])
            res = reg.fit()
            return res.params[0]/res.bse[0]
        #optimising the cointegration equation parameters
        res1 = spop.minimize(unit_root, data[stock2][t]/data[stock1][t], method='Nelder-Mead')
        t_opt = res1.fun
        b_opt = float(res1.x)
        a_opt = np.average(data[stock2][t-window:t] - b_opt*data[stock1][t-window:t])
        #simulating trading
        fair_value = a_opt + b_opt*data[stock1][t]
        if t == window:
            old_signal = 0
        if t_opt > t_threshold:
            signal = 0
            gross_return = 0
        else:
            signal = np.sign(fair_value - data[stock2][t])
            gross_return = signal*returns[stock2][t] - signal*returns[stock1][t]
        fees = fee*abs(signal - old_signal)
        net_return = gross_return - fees
        gross_returns = np.append(gross_returns, gross_return)
        net_returns = np.append(net_returns, net_return)
        t_s = np.append(t_s, t_opt)
        #interface: reporting daily positions and realised returns
        print('day '+str(data.index[t]))
        print('')
        if signal == 0:
            print('no trading')
        elif  signal == 1:
            print('long position on '+stock2+' and short position on '+stock1)
        else:
            print('long position on '+stock1+' and short position on '+stock2)
        print('gross daily return: '+str(round(gross_return*100,2))+'%')
        print('net daily return: '+str(round(net_return*100,2))+'%')
        print('cumulative net return so far: '+str(round(np.prod(1+net_returns)*100-100,2))+'%')
        print('')
        old_signal = signal
    #plotting equity curves
    plt.plot(np.append(1,np.cumprod(1+gross_returns)))
    plt.plot(np.append(1,np.cumprod(1+net_returns)))
# Out:
# day 2020-12-29 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-12-30 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
#
# day 2020-12-31 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -1.53%
# net daily return: -1.63%
# cumulative net return so far: -1.63%
#
# day 2021-01-04 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: -1.73%
#
# day 2021-01-05 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -1.73%
#
# day 2021-01-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -1.73%
#
# day 2021-01-07 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -1.73%
#
# day 2021-01-08 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -1.73%
#
# day 2021-01-11 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -1.73%
#
# day 2021-01-12 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -1.73%
#
# day 2021-01-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -1.73%
#
# day 2021-01-14 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -1.73%
#
# day 2021-01-15 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -1.73%
#
# day 2021-01-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -1.73%
#
# day 2021-01-20 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -1.73%
#
# day 2021-01-21 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -1.73%
#
# day 2021-01-22 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 4.02%
# net daily return: 3.92%
# cumulative net return so far: 2.12%
#
# day 2021-01-25 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: 2.02%
#
# day 2021-01-26 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 2.02%
#
# day 2021-01-27 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -5.26%
# net daily return: -5.36%
# cumulative net return so far: -3.45%
#
# day 2021-01-28 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -2.64%
# net daily return: -2.64%
# cumulative net return so far: -5.99%
#
# day 2021-01-29 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 0.91%
# net daily return: 0.91%
# cumulative net return so far: -5.13%
#
# day 2021-02-01 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -2.44%
# net daily return: -2.44%
# cumulative net return so far: -7.45%
#
# day 2021-02-02 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -1.92%
# net daily return: -1.92%
# cumulative net return so far: -9.23%
#
# day 2021-02-03 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 0.27%
# net daily return: 0.27%
# cumulative net return so far: -8.98%
#
# day 2021-02-04 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -0.26%
# net daily return: -0.26%
# cumulative net return so far: -9.22%
#
# day 2021-02-05 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -1.46%
# net daily return: -1.46%
# cumulative net return so far: -10.54%
#
# day 2021-02-08 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -0.26%
# net daily return: -0.26%
# cumulative net return so far: -10.77%
#
# day 2021-02-09 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -0.51%
# net daily return: -0.51%
# cumulative net return so far: -11.23%
#
# day 2021-02-10 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 0.09%
# net daily return: 0.09%
# cumulative net return so far: -11.15%
#
# day 2021-02-11 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -1.24%
# net daily return: -1.24%
# cumulative net return so far: -12.26%
#
# day 2021-02-12 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -4.02%
# net daily return: -4.02%
# cumulative net return so far: -15.78%
#
# day 2021-02-16 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -2.08%
# net daily return: -2.08%
# cumulative net return so far: -17.53%
#
# day 2021-02-17 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -1.2%
# net daily return: -1.2%
# cumulative net return so far: -18.52%
#
# day 2021-02-18 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -1.55%
# net daily return: -1.55%
# cumulative net return so far: -19.78%
#
# day 2021-02-19 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -3.92%
# net daily return: -3.92%
# cumulative net return so far: -22.93%
#
# day 2021-02-22 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -0.91%
# net daily return: -0.91%
# cumulative net return so far: -23.63%
#
# day 2021-02-23 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -2.16%
# net daily return: -2.16%
# cumulative net return so far: -25.28%
#
# day 2021-02-24 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -2.12%
# net daily return: -2.12%
# cumulative net return so far: -26.87%
#
# day 2021-02-25 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 2.88%
# net daily return: 2.88%
# cumulative net return so far: -24.76%
#
# day 2021-02-26 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 3.12%
# net daily return: 3.12%
# cumulative net return so far: -22.42%
#
# day 2021-03-01 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: -22.49%
#
# day 2021-03-02 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -4.38%
# net daily return: -4.48%
# cumulative net return so far: -25.96%
#
# day 2021-03-03 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: -26.04%
#
# day 2021-03-04 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-03-05 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-03-08 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-03-09 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-03-10 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-03-11 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-03-12 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-03-15 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-03-16 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-03-17 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-03-18 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-03-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-03-22 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-03-23 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-03-24 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-03-25 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-03-26 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-03-29 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-03-30 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-03-31 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-04-01 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-04-05 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-04-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-04-07 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-04-08 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-04-09 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.04%
#
# day 2021-04-12 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 3.62%
# net daily return: 3.52%
# cumulative net return so far: -23.43%
#
# day 2021-04-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: -23.51%
#
# day 2021-04-14 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.51%
#
# day 2021-04-15 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.51%
#
# day 2021-04-16 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.51%
#
# day 2021-04-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.51%
#
# day 2021-04-20 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.51%
#
# day 2021-04-21 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.51%
#
# day 2021-04-22 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.51%
#
# day 2021-04-23 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.51%
#
# day 2021-04-26 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.51%
#
# day 2021-04-27 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -23.51%
#
# day 2021-04-28 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 2.02%
# net daily return: 1.92%
# cumulative net return so far: -22.04%
#
# day 2021-04-29 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.62%
# net daily return: 0.62%
# cumulative net return so far: -21.55%
#
# day 2021-04-30 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: -21.63%
#
# day 2021-05-03 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 4.92%
# net daily return: 4.82%
# cumulative net return so far: -17.86%
#
# day 2021-05-04 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: -17.94%
#
# day 2021-05-05 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -17.94%
#
# day 2021-05-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -17.94%
#
# day 2021-05-07 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -17.94%
#
# day 2021-05-10 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -17.94%
#
# day 2021-05-11 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -17.94%
#
# day 2021-05-12 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -17.94%
#
# day 2021-05-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -17.94%
#
# day 2021-05-14 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -17.94%
#
# day 2021-05-17 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -17.94%
#
# day 2021-05-18 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -17.94%
#
# day 2021-05-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -17.94%
#
# day 2021-05-20 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -17.94%
#
# day 2021-05-21 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 0.79%
# net daily return: 0.69%
# cumulative net return so far: -17.37%
#
# day 2021-05-24 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -0.88%
# net daily return: -1.08%
# cumulative net return so far: -18.26%
#
# day 2021-05-25 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -0.03%
# net daily return: -0.23%
# cumulative net return so far: -18.45%
#
# day 2021-05-26 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -2.79%
# net daily return: -2.79%
# cumulative net return so far: -20.72%
#
# day 2021-05-27 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -0.47%
# net daily return: -0.47%
# cumulative net return so far: -21.1%
#
# day 2021-05-28 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -1.37%
# net daily return: -1.37%
# cumulative net return so far: -22.17%
#
# day 2021-06-01 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 0.62%
# net daily return: 0.62%
# cumulative net return so far: -21.69%
#
# day 2021-06-02 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -1.28%
# net daily return: -1.28%
# cumulative net return so far: -22.69%
#
# day 2021-06-03 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 1.74%
# net daily return: 1.74%
# cumulative net return so far: -21.35%
#
# day 2021-06-04 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 0.48%
# net daily return: 0.48%
# cumulative net return so far: -20.97%
#
# day 2021-06-07 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 1.07%
# net daily return: 1.07%
# cumulative net return so far: -20.13%
#
# day 2021-06-08 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 1.56%
# net daily return: 1.56%
# cumulative net return so far: -18.89%
#
# day 2021-06-09 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 0.76%
# net daily return: 0.76%
# cumulative net return so far: -18.28%
#
# day 2021-06-10 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 1.05%
# net daily return: 1.05%
# cumulative net return so far: -17.42%
#
# day 2021-06-11 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 4.15%
# net daily return: 4.15%
# cumulative net return so far: -13.99%
#
# day 2021-06-14 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -0.87%
# net daily return: -1.07%
# cumulative net return so far: -14.91%
#
# day 2021-06-15 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.31%
# net daily return: 0.31%
# cumulative net return so far: -14.65%
#
# day 2021-06-16 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -4.15%
# net daily return: -4.15%
# cumulative net return so far: -18.18%
#
# day 2021-06-17 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -1.52%
# net daily return: -1.52%
# cumulative net return so far: -19.43%
#
# day 2021-06-18 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.29%
# net daily return: 0.29%
# cumulative net return so far: -19.2%
#
# day 2021-06-21 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -1.42%
# net daily return: -1.42%
# cumulative net return so far: -20.34%
#
# day 2021-06-22 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.81%
# net daily return: 0.81%
# cumulative net return so far: -19.69%
#
# day 2021-06-23 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 1.14%
# net daily return: 1.14%
# cumulative net return so far: -18.78%
#
# day 2021-06-24 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 1.23%
# net daily return: 1.23%
# cumulative net return so far: -17.78%
#
# day 2021-06-25 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -1.07%
# net daily return: -1.07%
# cumulative net return so far: -18.66%
#
# day 2021-06-28 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -1.27%
# net daily return: -1.27%
# cumulative net return so far: -19.69%
#
# day 2021-06-29 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.45%
# net daily return: 0.45%
# cumulative net return so far: -19.34%
#
# day 2021-06-30 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.76%
# net daily return: 0.76%
# cumulative net return so far: -18.72%
#
# day 2021-07-01 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -2.63%
# net daily return: -2.63%
# cumulative net return so far: -20.86%
#
# day 2021-07-02 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -3.15%
# net daily return: -3.15%
# cumulative net return so far: -23.35%
#
# day 2021-07-06 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -1.68%
# net daily return: -1.68%
# cumulative net return so far: -24.64%
#
# day 2021-07-07 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -0.81%
# net daily return: -0.81%
# cumulative net return so far: -25.24%
#
# day 2021-07-08 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 1.89%
# net daily return: 1.89%
# cumulative net return so far: -23.83%
#
# day 2021-07-09 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 1.85%
# net daily return: 1.85%
# cumulative net return so far: -22.42%
#
# day 2021-07-12 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -2.28%
# net daily return: -2.28%
# cumulative net return so far: -24.18%
#
# day 2021-07-13 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -2.75%
# net daily return: -2.75%
# cumulative net return so far: -26.27%
#
# day 2021-07-14 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.67%
# net daily return: 0.67%
# cumulative net return so far: -25.78%
#
# day 2021-07-15 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -0.88%
# net daily return: -0.88%
# cumulative net return so far: -26.43%
#
# day 2021-07-16 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -0.56%
# net daily return: -0.56%
# cumulative net return so far: -26.84%
#
# day 2021-07-19 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -0.73%
# net daily return: -0.73%
# cumulative net return so far: -27.37%
#
# day 2021-07-20 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 2.62%
# net daily return: 2.62%
# cumulative net return so far: -25.47%
#
# day 2021-07-21 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -2.23%
# net daily return: -2.23%
# cumulative net return so far: -27.13%
#
# day 2021-07-22 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -1.39%
# net daily return: -1.39%
# cumulative net return so far: -28.15%
#
# day 2021-07-23 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.38%
# net daily return: 0.38%
# cumulative net return so far: -27.87%
#
# day 2021-07-26 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 1.36%
# net daily return: 1.36%
# cumulative net return so far: -26.89%
#
# day 2021-07-27 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 1.38%
# net daily return: 1.38%
# cumulative net return so far: -25.88%
#
# day 2021-07-28 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.4%
# net daily return: 0.4%
# cumulative net return so far: -25.58%
#
# day 2021-07-29 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -0.95%
# net daily return: -0.95%
# cumulative net return so far: -26.29%
#
# day 2021-07-30 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -0.17%
# net daily return: -0.17%
# cumulative net return so far: -26.41%
#
# day 2021-08-02 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -0.13%
# net daily return: -0.13%
# cumulative net return so far: -26.51%
#
# day 2021-08-03 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: -26.58%
#
# day 2021-08-04 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.58%
#
# day 2021-08-05 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.58%
#
# day 2021-08-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.58%
#
# day 2021-08-09 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.58%
#
# day 2021-08-10 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -26.58%
#
# day 2021-08-11 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -1.69%
# net daily return: -1.79%
# cumulative net return so far: -27.89%
#
# day 2021-08-12 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: -27.96%
#
# day 2021-08-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -27.96%
#
# day 2021-08-16 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -27.96%
#
# day 2021-08-17 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -27.96%
#
# day 2021-08-18 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -27.96%
#
# day 2021-08-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -27.96%
#
# day 2021-08-20 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -27.96%
#
# day 2021-08-23 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -27.96%
#
# day 2021-08-24 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -27.96%
#
# day 2021-08-25 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -27.96%
#
# day 2021-08-26 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -27.96%
#
# day 2021-08-27 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -27.96%
#
# day 2021-08-30 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -27.96%
#
# day 2021-08-31 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -27.96%
#
# day 2021-09-01 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -0.28%
# net daily return: -0.38%
# cumulative net return so far: -28.24%
#
# day 2021-09-02 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -1.03%
# net daily return: -1.03%
# cumulative net return so far: -28.98%
#
# day 2021-09-03 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: -29.05%
#
# day 2021-09-07 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-09-08 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-09-09 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-09-10 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-09-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-09-14 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-09-15 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-09-16 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-09-17 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-09-20 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-09-21 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-09-22 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-09-23 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-09-24 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-09-27 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-09-28 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-09-29 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-09-30 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-01 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-04 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-05 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-07 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-08 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-11 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-12 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-14 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-15 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-18 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-20 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-21 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-22 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-25 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-26 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-27 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.05%
#
# day 2021-10-28 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -1.54%
# net daily return: -1.64%
# cumulative net return so far: -30.21%
#
# day 2021-10-29 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -0.51%
# net daily return: -0.51%
# cumulative net return so far: -30.57%
#
# day 2021-11-01 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 0.32%
# net daily return: 0.32%
# cumulative net return so far: -30.35%
#
# day 2021-11-02 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 0.94%
# net daily return: 0.94%
# cumulative net return so far: -29.69%
#
# day 2021-11-03 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: -29.76%
#
# day 2021-11-04 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 0.35%
# net daily return: 0.25%
# cumulative net return so far: -29.58%
#
# day 2021-11-05 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -1.16%
# net daily return: -1.16%
# cumulative net return so far: -30.39%
#
# day 2021-11-08 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 1.0%
# net daily return: 1.0%
# cumulative net return so far: -29.7%
#
# day 2021-11-09 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: -29.77%
#
# day 2021-11-10 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.77%
#
# day 2021-11-11 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.77%
#
# day 2021-11-12 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.77%
#
# day 2021-11-15 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.77%
#
# day 2021-11-16 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.77%
#
# day 2021-11-17 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.77%
#
# day 2021-11-18 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.77%
#
# day 2021-11-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -29.77%
#
# day 2021-11-22 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -2.15%
# net daily return: -2.25%
# cumulative net return so far: -31.35%
#
# day 2021-11-23 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: -31.41%
#
# day 2021-11-24 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -31.41%
#
# day 2021-11-26 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -31.41%
#
# day 2021-11-29 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -31.41%
#
# day 2021-11-30 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -31.41%
#
# day 2021-12-01 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -31.41%
#
# day 2021-12-02 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -31.41%
#
# day 2021-12-03 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -31.41%
#
# day 2021-12-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -31.41%
#
# day 2021-12-07 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -31.41%
#
# day 2021-12-08 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -31.41%
#
# day 2021-12-09 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 3.2%
# net daily return: 3.1%
# cumulative net return so far: -29.29%
#
# day 2021-12-10 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -0.88%
# net daily return: -0.88%
# cumulative net return so far: -29.91%
#
# day 2021-12-13 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -1.57%
# net daily return: -1.57%
# cumulative net return so far: -31.01%
#
# day 2021-12-14 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 3.6%
# net daily return: 3.6%
# cumulative net return so far: -28.53%
#
# day 2021-12-15 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -5.49%
# net daily return: -5.49%
# cumulative net return so far: -32.45%
#
# day 2021-12-16 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 1.63%
# net daily return: 1.63%
# cumulative net return so far: -31.35%
#
# day 2021-12-17 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -0.99%
# net daily return: -1.19%
# cumulative net return so far: -32.17%
#
# day 2021-12-20 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -0.51%
# net daily return: -0.51%
# cumulative net return so far: -32.51%
#
# day 2021-12-21 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: 1.14%
# net daily return: 0.94%
# cumulative net return so far: -31.88%
#
# day 2021-12-22 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -0.01%
# net daily return: -0.21%
# cumulative net return so far: -32.02%
#
# day 2021-12-23 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -1.73%
# net daily return: -1.73%
# cumulative net return so far: -33.19%
#
# day 2021-12-27 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.88%
# net daily return: 0.88%
# cumulative net return so far: -32.6%
#
# day 2021-12-28 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -0.1%
# net daily return: -0.1%
# cumulative net return so far: -32.67%
#
# day 2021-12-29 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.61%
# net daily return: 0.61%
# cumulative net return so far: -32.26%
#
# day 2021-12-30 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.27%
# net daily return: 0.27%
# cumulative net return so far: -32.08%
#
# day 2021-12-31 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -0.38%
# net daily return: -0.38%
# cumulative net return so far: -32.34%
#
# day 2022-01-03 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -5.06%
# net daily return: -5.26%
# cumulative net return so far: -35.9%
#
# day 2022-01-04 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -0.25%
# net daily return: -0.25%
# cumulative net return so far: -36.06%
#
# day 2022-01-05 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -2.73%
# net daily return: -2.73%
# cumulative net return so far: -37.8%
#
# day 2022-01-06 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -0.89%
# net daily return: -0.89%
# cumulative net return so far: -38.36%
#
# day 2022-01-07 00:00:00
#
# long position on AAPL and short position on JPM
# gross daily return: -0.08%
# net daily return: -0.08%
# cumulative net return so far: -38.41%
#
# day 2022-01-10 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: -38.47%
#
# day 2022-01-11 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -38.47%
#
# day 2022-01-12 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -38.47%
#
# day 2022-01-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -38.47%
#
# day 2022-01-14 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -38.47%
#
# day 2022-01-18 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.56%
# net daily return: 0.46%
# cumulative net return so far: -38.19%
#
# day 2022-01-19 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.18%
# net daily return: 0.18%
# cumulative net return so far: -38.08%
#
# day 2022-01-20 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -0.47%
# net daily return: -0.47%
# cumulative net return so far: -38.37%
#
# day 2022-01-21 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.4%
# net daily return: 0.4%
# cumulative net return so far: -38.13%
#
# day 2022-01-24 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 2.23%
# net daily return: 2.23%
# cumulative net return so far: -36.75%
#
# day 2022-01-25 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 1.0%
# net daily return: 1.0%
# cumulative net return so far: -36.11%
#
# day 2022-01-26 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -1.47%
# net daily return: -1.47%
# cumulative net return so far: -37.05%
#
# day 2022-01-27 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -6.08%
# net daily return: -6.08%
# cumulative net return so far: -40.88%
#
# day 2022-01-28 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -1.26%
# net daily return: -1.26%
# cumulative net return so far: -41.62%
#
# day 2022-01-31 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 1.81%
# net daily return: 1.81%
# cumulative net return so far: -40.56%
#
# day 2022-02-01 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -1.5%
# net daily return: -1.5%
# cumulative net return so far: -41.46%
#
# day 2022-02-02 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.84%
# net daily return: 0.84%
# cumulative net return so far: -40.96%
#
# day 2022-02-03 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 2.89%
# net daily return: 2.89%
# cumulative net return so far: -39.26%
#
# day 2022-02-04 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.76%
# net daily return: 0.76%
# cumulative net return so far: -38.8%
#
# day 2022-02-07 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.03%
# net daily return: 0.03%
# cumulative net return so far: -38.78%
#
# day 2022-02-08 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -0.41%
# net daily return: -0.41%
# cumulative net return so far: -39.03%
#
# day 2022-02-09 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 1.94%
# net daily return: 1.94%
# cumulative net return so far: -37.84%
#
# day 2022-02-10 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.72%
# net daily return: 0.72%
# cumulative net return so far: -37.4%
#
# day 2022-02-11 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -1.07%
# net daily return: -1.07%
# cumulative net return so far: -38.07%
#
# day 2022-02-14 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -0.85%
# net daily return: -0.85%
# cumulative net return so far: -38.59%
#
# day 2022-02-15 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.32%
# net daily return: 0.32%
# cumulative net return so far: -38.4%
#
# day 2022-02-16 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -0.18%
# net daily return: -0.18%
# cumulative net return so far: -38.51%
#
# day 2022-02-17 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 1.4%
# net daily return: 1.4%
# cumulative net return so far: -37.64%
#
# day 2022-02-18 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 1.6%
# net daily return: 1.6%
# cumulative net return so far: -36.64%
#
# day 2022-02-22 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 0.49%
# net daily return: 0.49%
# cumulative net return so far: -36.33%
#
# day 2022-02-23 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -4.45%
# net daily return: -4.45%
# cumulative net return so far: -39.17%
#
# day 2022-02-24 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: 1.07%
# net daily return: 1.07%
# cumulative net return so far: -38.51%
#
# day 2022-02-25 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -4.33%
# net daily return: -4.33%
# cumulative net return so far: -41.18%
#
# day 2022-02-28 00:00:00
#
# long position on JPM and short position on AAPL
# gross daily return: -2.61%
# net daily return: -2.61%
# cumulative net return so far: -42.71%
#
# day 2022-03-01 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: -0.1%
# cumulative net return so far: -42.77%
#
# day 2022-03-02 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-03 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-04 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-07 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-08 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-09 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-10 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-11 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-14 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-15 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-16 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-17 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-18 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-21 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-22 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-23 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-24 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-25 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-28 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-29 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-30 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-03-31 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-01 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-04 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-05 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-07 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-08 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-11 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-12 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-14 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-18 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-20 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-21 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-22 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-25 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-26 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-27 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-28 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-04-29 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-02 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-03 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-04 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-05 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-09 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-10 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-11 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-12 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-16 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-17 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-18 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-20 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-23 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-24 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-25 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-26 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-27 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-05-31 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-01 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-02 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-03 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-07 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-08 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-09 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-10 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-14 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-15 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-16 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-17 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-21 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-22 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-23 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-24 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-27 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-28 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-29 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-06-30 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-07-01 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-07-05 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-07-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-07-07 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-07-08 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-07-11 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-07-12 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-07-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-07-14 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-07-15 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-07-18 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-07-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-07-20 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-07-21 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-07-22 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-07-25 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-07-26 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-07-27 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
#
# day 2022-07-28 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: -42.77%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [5], line 21
#      19     return res.params[0]/res.bse[0]
#      20 #optimising the cointegration equation parameters
# ---> 21 res1 = spop.minimize(unit_root, data[stock2][t]/data[stock1][t], method='Nelder-Mead')
#      22 t_opt = res1.fun
#      23 b_opt = float(res1.x)
#
# File c:\Users\Prithvie\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_minimize.py:687, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     684     bounds = standardize_bounds(bounds, x0, meth)
#     686 if meth == 'nelder-mead':
# --> 687     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     688                                **options)
#     689 elif meth == 'powell':
#     690     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File c:\Users\Prithvie\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_optimize.py:834, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     832 if bounds is not None:
#     833     xcc = np.clip(xcc, lower_bound, upper_bound)
# --> 834 fxcc = func(xcc)
#     836 if fxcc < fsim[-1]:
#     837     sim[-1] = xcc
#
# File c:\Users\Prithvie\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_optimize.py:496, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     494 ncalls[0] += 1
#     495 # A copy of x is sent to the user function (gh13740)
# --> 496 fx = function(np.copy(x), *(wrapper_args + args))
#     497 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     498 # backwards-compatibility, also allow np.array([1.3]),
#     499 # np.array([[1.3]]) etc.
#     500 if not np.isscalar(fx):
#
# Cell In [5], line 14, in unit_root(b)
#      12 def unit_root(b):
#      13     a = np.average(data[stock2][t-window:t] - b*data[stock1][t-window:t])
# ---> 14     fair_value = a + b*data[stock1][t-window:t]
#      15     diff = np.array(fair_value - data[stock2][t-window:t])
#      16     diff_diff = diff[1:] - diff[:-1]
#
# File c:\Users\Prithvie\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:2101, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2097 @final
#    2098 def __array_ufunc__(
#    2099     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2100 ):
# -> 2101     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File c:\Users\Prithvie\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:242, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     238     # signal that we didn't fallback / execute the ufunc yet
#     239     return NotImplemented
# --> 242 def array_ufunc(self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any):
#     243     """
#     244     Compatibility with numpy ufuncs.
#     245
#    (...)
#     248     numpy.org/doc/stable/reference/arrays.classes.html#numpy.class.__array_ufunc__
#     249     """
#     250     from pandas.core.generic import NDFrame
#
# KeyboardInterrupt:
